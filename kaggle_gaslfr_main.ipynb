# %% [markdown]
# # Google - American Sign Language Fingerspelling Recognition

# %% [markdown]
# ## tpu setting

# %%
import tensorflow as tf

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='')
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# WARNING:tensorflow:TPU system grpc://10.74.7.186:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# ## library

# %%
# !pip install transformers
# !pip install leven
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.32.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: leven in /usr/local/lib/python3.10/dist-packages (1.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from leven) (1.16.0)
# Requirement already satisfied: nose in /usr/local/lib/python3.10/dist-packages (from leven) (1.3.7)

# %%
import glob
import pandas as pd
from tqdm import tqdm
import time
import json
import random
import os

import torch
import torch.nn as nn
from torch.nn.utils import clip_grad_norm_, weight_norm

import numpy as np
import gc
from leven import levenshtein

from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

from transformers import BartConfig, BartModel, BartForConditionalGeneration,  GPT2Model, GPT2Config, RobertaPreLayerNormConfig, RobertaPreLayerNormModel
from transformers.optimization import get_cosine_schedule_with_warmup

from matplotlib import pyplot as plt

import tensorflow as tf
from keras import layers
from transformers import BartConfig, TFBartModel
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.optimizers.schedules import LearningRateSchedule

from keras import backend as K
from tensorflow.keras.optimizers import AdamW, Adam
from keras.losses import CategoricalCrossentropy
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import Sequence
import math
import keras

# %% [markdown]
# ## config

# %%
# select columns to be used.

LIP = [
    61, 185, 40, 39, 37, 0, 267, 269, 270, 409,
    291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
    78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
    95, 88, 178, 87, 14, 317, 402, 318, 324, 308
    ]

FRAME = ['frame']
LHAND = [f'x_left_hand_{i}' for i in range(21)] + [f'y_left_hand_{i}' for i in range(21)] + [f'z_left_hand_{i}' for i in range(21)]
RHAND = [f'x_right_hand_{i}' for i in range(21)] + [f'y_right_hand_{i}' for i in range(21)] + [f'z_right_hand_{i}' for i in range(21)]
POSE = [f'x_pose_{i}' for i in range(33)] + [f'y_pose_{i}' for i in range(33)] + [f'z_pose_{i}' for i in range(33)]
FACE = [f'x_face_{i}' for i in LIP] + [f'y_face_{i}' for i in LIP] + [f'z_face_{i}' for i in LIP]

cols = FRAME + LHAND + RHAND + POSE + FACE
len(cols)
# Out:
# 346

# %%
# CTC loss

class CustomConfig():
  path = '/content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/'
  seed = 42
  n_folds = 5
  columns = cols[1:]#LHAND + RHAND
  max_frame = 384
  max_label = 384
  concat_max_label = 43
  n_hand_landmarks = 21
  n_pose_landmarks = 33
  n_face_landmarks = 40
  n_landmarks = 115 #- 33 - 40
  encoder_pad_token = 0
  decoder_bos_token = 59
  decoder_eos_token = 60
  decoder_pad_token = 61
  blank_token = 62
  blank_string = 'ϵ'
  drop_z = True
  drop_nan = False
  vocab_size = 63
  use_suppl = True

  # custom model config

  input_dim = n_landmarks * 2 if drop_z else n_landmarks * 3
  hidden_dim = 256
  drop_rate = 0.2
  n_beams = 1


  # train config
  ignore_index = -100
  smoothing = 0.0
  n_epochs = 200
  early_stop = 200
  score_start_mode = 'epoch'
  score_start_epoch = 1
  score_start_train_acc = 0.8
  n_workers = 8
  lr = 1e-3
  batch_size = 128
  device = 'cuda'
  wd = 0.01
  warmup_ratio = 0.1
  clip_grad_norm = True
  max_norm = 5.0

  # inference config
  pytorch_model_path = '/content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/result-ctc6/best-acc-epoch200.bin'



if __name__ == "__main__":
  args = CustomConfig()

# %% [markdown]
# ## preprocess

# %%
def preprocess(args):
  train = pd.read_csv(args.path + 'Data Sources/train.csv')
  supplemental_metadata = pd.read_csv(args.path + 'Data Sources/supplemental_metadata.csv')
  supplemental_metadata = supplemental_metadata.drop(supplemental_metadata.index[[35589]]).reset_index(drop=True)

  print('num_of_train : ', len(train))
  print('num_of_supplemental_metadata : ', len(supplemental_metadata))

  participant_ids = np.array(sorted(list(set(list(train['participant_id'])))))

  kf = KFold(n_splits = args.n_folds, shuffle = False)

  folds = list()
  for train_index, val_index in kf.split(participant_ids):
    train_ids = participant_ids[train_index]
    val_ids = participant_ids[val_index]

    train_df = train[train['participant_id'].isin(train_ids)].reset_index(drop = True)
    if args.use_suppl:
      train_df = pd.concat([train_df, supplemental_metadata]).reset_index(drop = True)
    val_df = train[train['participant_id'].isin(val_ids)].reset_index(drop = True)

    folds.append([train_df, val_df])
  return folds, train, supplemental_metadata

if __name__ == "__main__":
  folds, train, supplemental_metadata = preprocess(args)
# Out:
# num_of_train :  67208
# num_of_supplemental_metadata :  52957

# %% [markdown]
# ## utils

# %%
def levenshtein_score(preds, trues, reduce='mean'):
  scores = []
  for i in range(len(preds)):
    pred, true = preds[i], trues[i]
    score = (len(true) - levenshtein(pred, true))/len(true)
    scores.append(score)
  if reduce == 'mean':
    return np.mean(scores)
  elif reduce == 'none':
    return scores

def lr_warmup_cosine_decay(global_step,
                           warmup_steps,
                           hold = 0,
                           total_steps=0,
                           start_lr=0.0,
                           target_lr=1e-3):
    # Cosine decay
    learning_rate = 0.5 * target_lr * (1 + np.cos(np.pi * (global_step - warmup_steps - hold) / float(total_steps - warmup_steps - hold)))

    # Target LR * progress of warmup (=1 at the final warmup step)
    warmup_lr = target_lr * (global_step / warmup_steps)

    # Choose between `warmup_lr`, `target_lr` and `learning_rate` based on whether `global_step < warmup_steps` and we're still holding.
    # i.e. warm up if we're still warming up and use cosine decayed lr otherwise
    if hold > 0:
        learning_rate = np.where(global_step > warmup_steps + hold,
                                 learning_rate, target_lr)

    learning_rate = np.where(global_step < warmup_steps, warmup_lr, learning_rate)
    return learning_rate

class WarmupCosineDecay(keras.callbacks.Callback):
    def __init__(self, total_steps=0, warmup_steps=0, start_lr=0.0, target_lr=1e-3, hold=0):

        super(WarmupCosineDecay, self).__init__()
        self.start_lr = start_lr
        self.hold = hold
        self.total_steps = total_steps
        self.global_step = 0
        self.target_lr = target_lr
        self.warmup_steps = warmup_steps
        self.lrs = []

    def on_batch_end(self, batch, logs=None):
        self.global_step = self.global_step + 1
        lr = self.model.optimizer.lr.numpy()
        self.lrs.append(lr)

    def on_batch_begin(self, batch, logs=None):
        lr = lr_warmup_cosine_decay(global_step=self.global_step,
                                    total_steps=self.total_steps,
                                    warmup_steps=self.warmup_steps,
                                    start_lr=self.start_lr,
                                    target_lr=self.target_lr,
                                    hold=self.hold)
        K.set_value(self.model.optimizer.lr, lr)

class TrainLoggerCallback(tf.keras.callbacks.Callback):
    def __init__(self, log_file, model, dataset):
        super().__init__()
        self.log_file = log_file
        self.model = model
        self.dataset = dataset

    def on_train_begin(self, logs=None):
        with open(self.log_file, 'a+') as f:
            f.write("train start! \n")

    def on_epoch_end(self, epoch, logs=None):
        with open(self.log_file, 'a') as f:
            f.write(f"epoch : {epoch+1}, lr : {self.model.optimizer.lr.numpy()}, loss : {logs['classifier_1_loss']}, val_loss : {logs['val_classifier_1_loss']}\n")

# %% [markdown]
# ## seed

# %%
def seed_everything(seed: int = 1):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)
    keras.utils.set_random_seed(seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# %% [markdown]
# ## gcs

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from typing import List

from google.cloud import storage

def set_bucket_public_iam(
    bucket_name: str = "your-bucket-name",
    members: List[str] = ["allUsers"],
):
    """Set a public IAM Policy to bucket"""
    # bucket_name = "your-bucket-name"

    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)

    policy = bucket.get_iam_policy(requested_policy_version=3)
    policy.bindings.append(
        {"role": "roles/storage.objectViewer", "members": members}
    )

    bucket.set_iam_policy(policy)

    print(f"Bucket {bucket.name} is now publicly readable")

def pre_process0(x):
    x = x[:args.max_frame]
    x = tf.where(tf.math.is_nan(x), tf.zeros_like(x), x)
    n_frames = tf.shape(x)[0]

    lhand = tf.transpose(tf.reshape(x[:, 0:63], (n_frames, 3, args.n_hand_landmarks)), (0, 2, 1))
    rhand = tf.transpose(tf.reshape(x[:, 63:126], (n_frames, 3, args.n_hand_landmarks)), (0, 2, 1))
    pose = tf.transpose(tf.reshape(x[:, 126:225], (n_frames, 3, args.n_pose_landmarks)), (0, 2, 1))
    face = tf.transpose(tf.reshape(x[:, 225:345], (n_frames, 3, args.n_face_landmarks)), (0, 2, 1))

    x = tf.concat([
        lhand,
        rhand,
        pose,
        face
        ], axis=1)

    x = x[:, :, :2]
    return x
set_bucket_public_iam('gaslfr')
# Out:
# Bucket gaslfr is now publicly readable

# %% [markdown]
# ## stronger concat

# %%
def reverse_frames(x, y):
    x = x[::-1]
    y = y[::-1]
    return x, y

def flip_hand(video):
    video = tf.reshape(video, shape=(-1, args.n_landmarks, 2))
    hands = video[:, :int(2 * args.n_hand_landmarks)]
    other = video[:, int(2 * args.n_hand_landmarks):]

    lhand = hands[:, :args.n_hand_landmarks]
    rhand = hands[:, args.n_hand_landmarks:]

    lhand_x, rhand_x = lhand[:, :, 0], rhand[:, :, 0]
    lhand_x = tf.negative(lhand_x) + 2 * tf.reduce_mean(lhand_x, axis=1, keepdims=True)
    rhand_x = tf.negative(rhand_x) + 2 * tf.reduce_mean(rhand_x, axis=1, keepdims=True)

    lhand = tf.concat([tf.expand_dims(lhand_x, axis=-1), lhand[:, :, 1:]], axis=-1)
    rhand = tf.concat([tf.expand_dims(rhand_x, axis=-1), rhand[:, :, 1:]], axis=-1)

    flipped_hands = tf.concat([rhand, lhand, other], axis=1)
    flipped_hands = tf.reshape(flipped_hands, shape=(-1, args.input_dim))
    return flipped_hands

def augment_fn(x, y):
    def reverse_fn():
        return reverse_frames(x, y)

    def flip_fn():
        return flip_hand(x)

    should_reverse = tf.random.uniform(()) < 0.5
    should_flip = tf.random.uniform(()) < 0.5

    x, y = tf.cond(should_reverse, reverse_fn, lambda: (x, y))
    x = tf.cond(should_flip, flip_fn, lambda: x)

    return x, y

def cat_augment(inputs, _inputs):
    x, y = inputs
    _x, _y = _inputs

    x_shape = tf.shape(x)
    _x_shape = tf.shape(_x)

    x_condition = (x_shape[0] + _x_shape[0] < args.max_frame)

    x = tf.cond(x_condition, lambda: tf.concat([x, _x], axis=0), lambda: x)
    y = tf.cond(x_condition, lambda: tf.concat([y, _y], axis=0), lambda: y)

    return x, y


def decode_fn(record_bytes, augment=False):
    schema = {
        'coordinates': tf.io.VarLenFeature(tf.float32),
        'phrase': tf.io.VarLenFeature(tf.int64)
    }
    x = tf.io.parse_single_example(record_bytes, schema)

    coordinates = tf.reshape(tf.sparse.to_dense(x["coordinates"]), (-1, args.input_dim))
    phrase = tf.sparse.to_dense(x["phrase"])

    if augment:
      coordinates, phrase = augment_fn(coordinates, phrase)

    dx = tf.cond(tf.shape(coordinates)[0]>1,lambda:tf.pad(coordinates[1:] - coordinates[:-1], [[0,1],[0,0]]),lambda:tf.zeros_like(coordinates))
    coordinates = tf.concat([coordinates, dx], axis=-1)

    return coordinates, phrase

# %%
folds, train, supplemental_metadata = preprocess(args)
train_df, val_df = folds[0]

train_tffiles = tf.io.gfile.glob('gs://gaslfr/TfrecordsV2/train_tfds/*')
val_tffiles = tf.io.gfile.glob('gs://gaslfr/TfrecordsV2/val_tfds/*')
weight_tffiles = ['gs://gaslfr/TfrecordsV2/train_tfds/' + x.split('/')[-1] for x in val_tffiles]

trainall = True
if trainall:
  train_df = pd.concat([train_df, val_df]).reset_index(drop=True)
  train_tffiles = train_tffiles + val_tffiles
  weight_tffiles = weight_tffiles + val_tffiles

train_loader1 = tf.data.TFRecordDataset(train_tffiles).map(lambda x: decode_fn(x, augment=True), tf.data.AUTOTUNE).shuffle(buffer_size=len(train_df), seed=args.seed, reshuffle_each_iteration=True)
train_loader2 = tf.data.TFRecordDataset(train_tffiles).map(lambda x: decode_fn(x, augment=True), tf.data.AUTOTUNE).shuffle(buffer_size=len(train_df), seed=args.seed+1, reshuffle_each_iteration=True)

train_loader = tf.data.Dataset.zip((train_loader1, train_loader2))
train_loader = train_loader.map(cat_augment)

weight_loader = tf.data.TFRecordDataset(weight_tffiles).map(lambda x: decode_fn(x, augment=True), tf.data.AUTOTUNE)

train_loader = train_loader.concatenate(weight_loader)
train_loader = train_loader.shuffle(buffer_size=len(train_df) + len(train), seed=args.seed+2, reshuffle_each_iteration=True)
train_loader = train_loader.padded_batch(args.batch_size,
                                         padding_values=(tf.constant(0, dtype=tf.float32), tf.constant(args.decoder_pad_token, dtype=tf.int64)),
                                         padded_shapes=([args.max_frame,2*args.input_dim],[args.max_label]),
                                         drop_remainder=True).prefetch(tf.data.AUTOTUNE)

val_loader = tf.data.TFRecordDataset(val_tffiles).map(decode_fn)
val_loader = val_loader.padded_batch(args.batch_size,
                                     padding_values=(tf.constant(0, dtype=tf.float32), tf.constant(args.decoder_pad_token, dtype=tf.int64)),
                                     padded_shapes=([args.max_frame,2*args.input_dim],[args.max_label]),
                                     drop_remainder=True).prefetch(tf.data.AUTOTUNE)
# Out:
# num_of_train :  67208
# num_of_supplemental_metadata :  52957

# %%
len(train_tffiles), len(val_tffiles)
# Out:
# (189, 68)

# %% [markdown]
# ## lossV2

# %%
from shutil import copyfile
copyfile(src = "/content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/CTC_TPU.py", dst = "/content/CTC_TPU.py")
from CTC_TPU import classic_ctc_loss

@tf.function
def ctc_loss(y_true, y_pred):

    batch = tf.cast(tf.shape(y_true)[0], dtype="int64")

    input_length = args.max_label * tf.ones(shape=(batch), dtype="int64")
    label_length = tf.math.not_equal(y_true, args.decoder_pad_token)
    label_length = tf.reduce_sum(tf.cast(label_length, dtype="int64"), axis=1)

    y_pred = tf.reshape(y_pred, (batch, args.max_label, args.vocab_size))
    y_true = tf.reshape(y_true, (batch, args.max_label))
    input_length = tf.squeeze(tf.reshape(input_length, (batch, 1)), axis=1)
    label_length = tf.squeeze(tf.reshape(label_length, (batch, 1)), axis=1)

    #loss = tf.nn.ctc_loss(
    #    labels=tf.cast(y_true, tf.int32),
    #    logit_length=tf.cast(input_length, tf.int32),
    #    logits=tf.cast(y_pred, tf.float32),
    #    label_length=tf.cast(label_length, tf.int32),
    #    logits_time_major=False,
    #    blank_index=args.blank_token,
    #)

    loss = classic_ctc_loss(
            labels=tf.cast(y_true, tf.int32),
            logits=tf.cast(y_pred, tf.float32),
            label_length=tf.cast(label_length, tf.int32),
            logit_length=tf.cast(input_length, tf.int32),
            blank_index=args.blank_token,
        )
    loss = tf.where(tf.math.is_finite(loss), loss, tf.zeros_like(loss))
    #loss = loss/tf.cast(label_length, dtype=tf.float32)
    loss = tf.nn.compute_average_loss(loss, global_batch_size=args.batch_size)

    return loss

# %% [markdown]
# ## model

# %%
# nomask

class ECA(tf.keras.layers.Layer):
    def __init__(self, kernel_size=5, **kwargs):
        super().__init__(**kwargs)
        self.supports_masking = True
        self.kernel_size = kernel_size
        self.conv = tf.keras.layers.Conv1D(1, kernel_size=kernel_size, strides=1, padding="same", use_bias=False)

    def call(self, inputs, mask=None):
        nn = tf.keras.layers.GlobalAveragePooling1D()(inputs, mask=mask)
        nn = tf.expand_dims(nn, -1)
        nn = self.conv(nn)
        nn = tf.squeeze(nn, -1)
        nn = tf.nn.sigmoid(nn)
        nn = nn[:,None,:]
        return inputs * nn

class LateDropout(tf.keras.layers.Layer):
    def __init__(self, rate, noise_shape=None, start_step=0, **kwargs):
        super().__init__(**kwargs)
        self.supports_masking = True
        self.rate = rate
        self.start_step = start_step
        self.dropout = tf.keras.layers.Dropout(rate, noise_shape=noise_shape)

    def build(self, input_shape):
        super().build(input_shape)
        agg = tf.VariableAggregation.ONLY_FIRST_REPLICA
        self._train_counter = tf.Variable(0, dtype="int64", aggregation=agg, trainable=False)

    def call(self, inputs, training=False):
        x = tf.cond(self._train_counter < self.start_step, lambda:inputs, lambda:self.dropout(inputs, training=training))
        if training:
            self._train_counter.assign_add(1)
        return x

class CausalDWConv1D(tf.keras.layers.Layer):
    def __init__(self,
        kernel_size=17,
        dilation_rate=1,
        use_bias=False,
        depthwise_initializer='glorot_uniform',
        name='', **kwargs):
        super().__init__(name=name,**kwargs)
        #self.causal_pad = tf.keras.layers.ZeroPadding1D((dilation_rate*(kernel_size-1),0),name=name + '_pad')
        self.dw_conv = tf.keras.layers.DepthwiseConv1D(
                            kernel_size,
                            strides=1,
                            dilation_rate=dilation_rate,
                            padding='same',#padding='valid',
                            use_bias=use_bias,
                            depthwise_initializer=depthwise_initializer,
                            name=name + '_dwconv')
        self.supports_masking = True

    def call(self, inputs):
        x = inputs#x = self.causal_pad(inputs)
        x = self.dw_conv(x)
        return x

def Conv1DBlock(channel_size,
          kernel_size,
          dilation_rate=1,
          drop_rate=0.0,
          expand_ratio=2,
          se_ratio=0.25,
          activation='swish',
          name=None):
    '''
    efficient conv1d block, @hoyso48
    '''
    if name is None:
        name = str(tf.keras.backend.get_uid("mbblock"))
    # Expansion phase
    def apply(inputs):
        channels_in = tf.keras.backend.int_shape(inputs)[-1]
        channels_expand = channels_in * expand_ratio

        skip = inputs

        x = tf.keras.layers.Dense(
            channels_expand,
            use_bias=True,
            activation=activation,
            name=name + '_expand_conv')(inputs)

        # Depthwise Convolution
        x = CausalDWConv1D(kernel_size,
            dilation_rate=dilation_rate,
            use_bias=False,
            name=name + '_dwconv')(x)

        x = tf.keras.layers.BatchNormalization(momentum=0.95, name=name + '_bn')(x)

        x  = ECA()(x)

        x = tf.keras.layers.Dense(
            channel_size,
            use_bias=True,
            name=name + '_project_conv')(x)

        if drop_rate > 0:
            x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1), name=name + '_drop')(x)

        if (channels_in == channel_size):
            x = tf.keras.layers.add([x, skip], name=name + '_add')
        return x

    return apply
class MultiHeadSelfAttention(tf.keras.layers.Layer):
    def __init__(self, dim=256, num_heads=4, dropout=0, **kwargs):
        super().__init__(**kwargs)
        self.dim = dim
        self.scale = self.dim ** -0.5
        self.num_heads = num_heads
        self.qkv = tf.keras.layers.Dense(3 * dim, use_bias=False)
        self.drop1 = tf.keras.layers.Dropout(dropout)
        self.proj = tf.keras.layers.Dense(dim, use_bias=False)
        self.supports_masking = True

    def call(self, inputs, mask=None):
        qkv = self.qkv(inputs)
        qkv = tf.keras.layers.Permute((2, 1, 3))(tf.keras.layers.Reshape((-1, self.num_heads, self.dim * 3 // self.num_heads))(qkv))
        q, k, v = tf.split(qkv, [self.dim // self.num_heads] * 3, axis=-1)

        attn = tf.matmul(q, k, transpose_b=True) * self.scale

        #if mask is not None:
        #    mask = mask[:, None, None, :]

        attn = tf.keras.layers.Softmax(axis=-1)(attn, mask=None)#attn = tf.keras.layers.Softmax(axis=-1)(attn, mask=mask)
        attn = self.drop1(attn)

        x = attn @ v
        x = tf.keras.layers.Reshape((-1, self.dim))(tf.keras.layers.Permute((2, 1, 3))(x))
        x = self.proj(x)
        return x


def TransformerBlock(dim=256, num_heads=4, expand=4, attn_dropout=0.2, drop_rate=0.2, activation='swish'):
    def apply(inputs):
        x = inputs
        x = tf.keras.layers.BatchNormalization(momentum=0.95)(x)
        x = MultiHeadSelfAttention(dim=dim,num_heads=num_heads,dropout=attn_dropout)(x)
        x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1))(x)
        x = tf.keras.layers.Add()([inputs, x])
        attn_out = x

        x = tf.keras.layers.BatchNormalization(momentum=0.95)(x)
        x = tf.keras.layers.Dense(dim*expand, use_bias=False, activation=activation)(x)
        x = tf.keras.layers.Dense(dim, use_bias=False)(x)
        x = tf.keras.layers.Dropout(drop_rate, noise_shape=(None,1,1))(x)
        x = tf.keras.layers.Add()([attn_out, x])
        return x
    return apply

# %%
# interCTC

policy = tf.keras.mixed_precision.Policy('float32')
tf.keras.mixed_precision.set_global_policy(policy)

def get_model(max_len=384,
              dropout_step=0,
              dim=160,
              CHANNELS=230,
              NUM_CLASSES=63,
              PAD=0,
              ksize=31,
              drop_rate=0.1,
              num_layers=16):

    inp = tf.keras.Input((None,2*CHANNELS))
    x = inp
    x = tf.keras.layers.Dense(dim, use_bias=False,name='stem_conv')(x)
    x = tf.keras.layers.BatchNormalization(momentum=0.95,name='stem_bn')(x)

    xs = []
    for i in range(num_layers):
        x = TransformerBlock(dim,expand=2)(x)
        x = Conv1DBlock(dim,ksize,drop_rate=drop_rate)(x)
        xs.append(x)

    classifier = tf.keras.layers.Dense(NUM_CLASSES,name='classifier')

    x1 = LateDropout(0.2, start_step=dropout_step)(xs[-8])
    x1 = classifier(x1)

    x2 = LateDropout(0.2, start_step=dropout_step)(xs[-1])
    x2 = classifier(x2)
    return tf.keras.Model(inp, [x1, x2])

model = get_model()
input_shape = (args.max_label, 2*args.input_dim)
inputs = tf.keras.layers.Input(shape=input_shape, name='input')
model(inputs)
# Out:
# [<KerasTensor: shape=(None, 384, 63) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(None, 384, 63) dtype=float32 (created by layer 'model')>]

# %% [markdown]
# ## run

# %%
tf.config.run_functions_eagerly(False)

path = '/content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/'

policy = tf.keras.mixed_precision.Policy('float32')
tf.keras.mixed_precision.set_global_policy(policy)

seed_everything(args.seed)
print('number of train data : ', len(train_df))
print('number of val data : ', len(val_df))
print('seed : ', args.seed)

log_file = path + "./log.txt"

if not os.path.exists(path):
  os.makedirs(path)

weights_name = "weights/epoch_{epoch:02d}-val_loss_{val_classifier_1_loss:.4f}.h5"

checkpoint = ModelCheckpoint(path + weights_name,
                             monitor='val_classifier_1_loss',
                             verbose=1,
                             save_weights_only=True,
                             mode='max')


with strategy.scope():
  model = get_model()
  input_shape = (args.max_label, 2*args.input_dim)
  inputs = keras.layers.Input(shape=input_shape, name='input')
  model(inputs)

  optimizer = AdamW(learning_rate=args.lr, weight_decay=args.wd, global_clipnorm=args.max_norm)
  loss = ctc_loss
  inter_loss = ctc_loss


  model.compile(
      optimizer=optimizer,
      jit_compile=True
  )

  model.compile(
    loss=[inter_loss, loss],
    loss_weights=[0.3, 0.7]
  )

total_steps = ((len(train_df) + len(train)) // args.batch_size) * args.n_epochs
warmup_steps = int(args.warmup_ratio*total_steps)
print('total_steps: ', total_steps)
print('warmup_steps: ', warmup_steps)


callback = WarmupCosineDecay(total_steps=total_steps,
                             warmup_steps=warmup_steps,
                             hold=0,
                             start_lr=0.0,
                             target_lr=args.lr)

logger = TrainLoggerCallback(log_file, model, val_loader)

model.fit(
    train_loader ,
    validation_data = val_loader,
    epochs = args.n_epochs,
    verbose = 1,
    callbacks = [callback, logger, checkpoint]
  )
# Out:
# number of train data :  120165
# number of val data :  13339
# seed :  42
# total_steps:  292600
# warmup_steps:  29260
# Epoch 1/200
#    1463/Unknown - 478s 151ms/step - loss: 49.3608 - classifier_loss: 45.8915 - classifier_1_loss: 50.8475
# Epoch 1: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_01-val_loss_8.1849.h5
# 1463/1463 [==============================] - 496s 163ms/step - loss: 49.3608 - classifier_loss: 45.8915 - classifier_1_loss: 50.8475 - val_loss: 8.2050 - val_classifier_loss: 8.2521 - val_classifier_1_loss: 8.1849
# Epoch 2/200
# 1463/1463 [==============================] - ETA: 0s - loss: 13.4344 - classifier_loss: 13.4503 - classifier_1_loss: 13.4276
# Epoch 2: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_02-val_loss_7.3855.h5
# 1463/1463 [==============================] - 306s 157ms/step - loss: 13.4344 - classifier_loss: 13.4503 - classifier_1_loss: 13.4276 - val_loss: 7.4382 - val_classifier_loss: 7.5612 - val_classifier_1_loss: 7.3855
# Epoch 3/200
# 1463/1463 [==============================] - ETA: 0s - loss: 10.4321 - classifier_loss: 10.6854 - classifier_1_loss: 10.3236
# Epoch 3: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_03-val_loss_4.9714.h5
# 1463/1463 [==============================] - 308s 159ms/step - loss: 10.4321 - classifier_loss: 10.6854 - classifier_1_loss: 10.3236 - val_loss: 5.0611 - val_classifier_loss: 5.2705 - val_classifier_1_loss: 4.9714
# Epoch 4/200
# 1463/1463 [==============================] - ETA: 0s - loss: 8.2640 - classifier_loss: 8.5732 - classifier_1_loss: 8.1315
# Epoch 4: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_04-val_loss_4.4155.h5
# 1463/1463 [==============================] - 307s 159ms/step - loss: 8.2640 - classifier_loss: 8.5732 - classifier_1_loss: 8.1315 - val_loss: 4.5154 - val_classifier_loss: 4.7485 - val_classifier_1_loss: 4.4155
# Epoch 5/200
# 1463/1463 [==============================] - ETA: 0s - loss: 7.2974 - classifier_loss: 7.6220 - classifier_1_loss: 7.1583
# Epoch 5: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_05-val_loss_4.0811.h5
# 1463/1463 [==============================] - 308s 160ms/step - loss: 7.2974 - classifier_loss: 7.6220 - classifier_1_loss: 7.1583 - val_loss: 4.1825 - val_classifier_loss: 4.4189 - val_classifier_1_loss: 4.0811
# Epoch 6/200
# 1463/1463 [==============================] - ETA: 0s - loss: 6.6570 - classifier_loss: 6.9955 - classifier_1_loss: 6.5119
# Epoch 6: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_06-val_loss_3.6447.h5
# 1463/1463 [==============================] - 306s 159ms/step - loss: 6.6570 - classifier_loss: 6.9955 - classifier_1_loss: 6.5119 - val_loss: 3.7434 - val_classifier_loss: 3.9739 - val_classifier_1_loss: 3.6447
# Epoch 7/200
# 1463/1463 [==============================] - ETA: 0s - loss: 6.2117 - classifier_loss: 6.5620 - classifier_1_loss: 6.0615
# Epoch 7: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_07-val_loss_3.5328.h5
# 1463/1463 [==============================] - 306s 159ms/step - loss: 6.2117 - classifier_loss: 6.5620 - classifier_1_loss: 6.0615 - val_loss: 3.6110 - val_classifier_loss: 3.7937 - val_classifier_1_loss: 3.5328
# Epoch 8/200
# 1463/1463 [==============================] - ETA: 0s - loss: 5.8656 - classifier_loss: 6.2276 - classifier_1_loss: 5.7105
# Epoch 8: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_08-val_loss_3.3200.h5
# 1463/1463 [==============================] - 307s 158ms/step - loss: 5.8656 - classifier_loss: 6.2276 - classifier_1_loss: 5.7105 - val_loss: 3.4065 - val_classifier_loss: 3.6084 - val_classifier_1_loss: 3.3200
# Epoch 9/200
# 1463/1463 [==============================] - ETA: 0s - loss: 5.6098 - classifier_loss: 5.9816 - classifier_1_loss: 5.4504
# Epoch 9: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_09-val_loss_3.0820.h5
# 1463/1463 [==============================] - 305s 158ms/step - loss: 5.6098 - classifier_loss: 5.9816 - classifier_1_loss: 5.4504 - val_loss: 3.1707 - val_classifier_loss: 3.3778 - val_classifier_1_loss: 3.0820
# Epoch 10/200
# 1463/1463 [==============================] - ETA: 0s - loss: 5.4034 - classifier_loss: 5.7839 - classifier_1_loss: 5.2403
# Epoch 10: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_10-val_loss_2.9957.h5
# 1463/1463 [==============================] - 306s 159ms/step - loss: 5.4034 - classifier_loss: 5.7839 - classifier_1_loss: 5.2403 - val_loss: 3.0801 - val_classifier_loss: 3.2769 - val_classifier_1_loss: 2.9957
# Epoch 11/200
# 1463/1463 [==============================] - ETA: 0s - loss: 5.2311 - classifier_loss: 5.6210 - classifier_1_loss: 5.0641
# Epoch 11: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_11-val_loss_2.9817.h5
# 1463/1463 [==============================] - 304s 158ms/step - loss: 5.2311 - classifier_loss: 5.6210 - classifier_1_loss: 5.0641 - val_loss: 3.0673 - val_classifier_loss: 3.2671 - val_classifier_1_loss: 2.9817
# Epoch 12/200
# 1463/1463 [==============================] - ETA: 0s - loss: 5.1015 - classifier_loss: 5.5021 - classifier_1_loss: 4.9298
# Epoch 12: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_12-val_loss_2.9781.h5
# 1463/1463 [==============================] - 304s 158ms/step - loss: 5.1015 - classifier_loss: 5.5021 - classifier_1_loss: 4.9298 - val_loss: 3.0647 - val_classifier_loss: 3.2665 - val_classifier_1_loss: 2.9781
# Epoch 13/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.9965 - classifier_loss: 5.4085 - classifier_1_loss: 4.8199
# Epoch 13: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_13-val_loss_2.7832.h5
# 1463/1463 [==============================] - 302s 159ms/step - loss: 4.9965 - classifier_loss: 5.4085 - classifier_1_loss: 4.8199 - val_loss: 2.8856 - val_classifier_loss: 3.1245 - val_classifier_1_loss: 2.7832
# Epoch 14/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.9009 - classifier_loss: 5.3252 - classifier_1_loss: 4.7190
# Epoch 14: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_14-val_loss_2.7229.h5
# 1463/1463 [==============================] - 305s 159ms/step - loss: 4.9009 - classifier_loss: 5.3252 - classifier_1_loss: 4.7190 - val_loss: 2.8130 - val_classifier_loss: 3.0233 - val_classifier_1_loss: 2.7229
# Epoch 15/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.8177 - classifier_loss: 5.2549 - classifier_1_loss: 4.6303
# Epoch 15: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_15-val_loss_2.6706.h5
# 1463/1463 [==============================] - 303s 159ms/step - loss: 4.8177 - classifier_loss: 5.2549 - classifier_1_loss: 4.6303 - val_loss: 2.7654 - val_classifier_loss: 2.9864 - val_classifier_1_loss: 2.6706
# Epoch 16/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.7570 - classifier_loss: 5.2080 - classifier_1_loss: 4.5638
# Epoch 16: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_16-val_loss_2.6247.h5
# 1463/1463 [==============================] - 299s 158ms/step - loss: 4.7570 - classifier_loss: 5.2080 - classifier_1_loss: 4.5638 - val_loss: 2.7201 - val_classifier_loss: 2.9427 - val_classifier_1_loss: 2.6247
# Epoch 17/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.6866 - classifier_loss: 5.1536 - classifier_1_loss: 4.4864
# Epoch 17: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_17-val_loss_2.6234.h5
# 1463/1463 [==============================] - 300s 158ms/step - loss: 4.6866 - classifier_loss: 5.1536 - classifier_1_loss: 4.4864 - val_loss: 2.7252 - val_classifier_loss: 2.9628 - val_classifier_1_loss: 2.6234
# Epoch 18/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.6210 - classifier_loss: 5.1026 - classifier_1_loss: 4.4145
# Epoch 18: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_18-val_loss_2.7369.h5
# 1463/1463 [==============================] - 299s 158ms/step - loss: 4.6210 - classifier_loss: 5.1026 - classifier_1_loss: 4.4145 - val_loss: 2.8405 - val_classifier_loss: 3.0823 - val_classifier_1_loss: 2.7369
# Epoch 19/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.5670 - classifier_loss: 5.0628 - classifier_1_loss: 4.3546
# Epoch 19: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_19-val_loss_2.5077.h5
# 1463/1463 [==============================] - 299s 157ms/step - loss: 4.5670 - classifier_loss: 5.0628 - classifier_1_loss: 4.3546 - val_loss: 2.6052 - val_classifier_loss: 2.8328 - val_classifier_1_loss: 2.5077
# Epoch 20/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.5203 - classifier_loss: 5.0285 - classifier_1_loss: 4.3026
# Epoch 20: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_20-val_loss_2.4516.h5
# 1463/1463 [==============================] - 298s 158ms/step - loss: 4.5203 - classifier_loss: 5.0285 - classifier_1_loss: 4.3026 - val_loss: 2.5552 - val_classifier_loss: 2.7971 - val_classifier_1_loss: 2.4516
# Epoch 21/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.4455 - classifier_loss: 4.9656 - classifier_1_loss: 4.2226
# Epoch 21: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_21-val_loss_2.4172.h5
# 1463/1463 [==============================] - 297s 157ms/step - loss: 4.4455 - classifier_loss: 4.9656 - classifier_1_loss: 4.2226 - val_loss: 2.5282 - val_classifier_loss: 2.7871 - val_classifier_1_loss: 2.4172
# Epoch 22/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.3740 - classifier_loss: 4.9053 - classifier_1_loss: 4.1463
# Epoch 22: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_22-val_loss_2.3244.h5
# 1463/1463 [==============================] - 295s 158ms/step - loss: 4.3740 - classifier_loss: 4.9053 - classifier_1_loss: 4.1463 - val_loss: 2.4365 - val_classifier_loss: 2.6981 - val_classifier_1_loss: 2.3244
# Epoch 23/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.2965 - classifier_loss: 4.8379 - classifier_1_loss: 4.0645
# Epoch 23: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_23-val_loss_2.4139.h5
# 1463/1463 [==============================] - 299s 159ms/step - loss: 4.2965 - classifier_loss: 4.8379 - classifier_1_loss: 4.0645 - val_loss: 2.5360 - val_classifier_loss: 2.8209 - val_classifier_1_loss: 2.4139
# Epoch 24/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.2273 - classifier_loss: 4.7778 - classifier_1_loss: 3.9914
# Epoch 24: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_24-val_loss_2.3933.h5
# 1463/1463 [==============================] - 298s 158ms/step - loss: 4.2273 - classifier_loss: 4.7778 - classifier_1_loss: 3.9914 - val_loss: 2.5050 - val_classifier_loss: 2.7656 - val_classifier_1_loss: 2.3933
# Epoch 25/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.1725 - classifier_loss: 4.7343 - classifier_1_loss: 3.9317
# Epoch 25: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_25-val_loss_2.2380.h5
# 1463/1463 [==============================] - 297s 157ms/step - loss: 4.1725 - classifier_loss: 4.7343 - classifier_1_loss: 3.9317 - val_loss: 2.3538 - val_classifier_loss: 2.6239 - val_classifier_1_loss: 2.2380
# Epoch 26/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.1062 - classifier_loss: 4.6729 - classifier_1_loss: 3.8633
# Epoch 26: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_26-val_loss_2.1690.h5
# 1463/1463 [==============================] - 298s 159ms/step - loss: 4.1062 - classifier_loss: 4.6729 - classifier_1_loss: 3.8633 - val_loss: 2.2926 - val_classifier_loss: 2.5808 - val_classifier_1_loss: 2.1690
# Epoch 27/200
# 1463/1463 [==============================] - ETA: 0s - loss: 4.0485 - classifier_loss: 4.6224 - classifier_1_loss: 3.8025
# Epoch 27: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_27-val_loss_2.1307.h5
# 1463/1463 [==============================] - 298s 158ms/step - loss: 4.0485 - classifier_loss: 4.6224 - classifier_1_loss: 3.8025 - val_loss: 2.2521 - val_classifier_loss: 2.5355 - val_classifier_1_loss: 2.1307
# Epoch 28/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.9962 - classifier_loss: 4.5763 - classifier_1_loss: 3.7475
# Epoch 28: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_28-val_loss_2.1240.h5
# 1463/1463 [==============================] - 296s 158ms/step - loss: 3.9962 - classifier_loss: 4.5763 - classifier_1_loss: 3.7475 - val_loss: 2.2442 - val_classifier_loss: 2.5247 - val_classifier_1_loss: 2.1240
# Epoch 29/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.9548 - classifier_loss: 4.5435 - classifier_1_loss: 3.7025
# Epoch 29: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_29-val_loss_2.0890.h5
# 1463/1463 [==============================] - 297s 158ms/step - loss: 3.9548 - classifier_loss: 4.5435 - classifier_1_loss: 3.7025 - val_loss: 2.2226 - val_classifier_loss: 2.5344 - val_classifier_1_loss: 2.0890
# Epoch 30/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.9094 - classifier_loss: 4.5073 - classifier_1_loss: 3.6532
# Epoch 30: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_30-val_loss_2.0653.h5
# 1463/1463 [==============================] - 296s 158ms/step - loss: 3.9094 - classifier_loss: 4.5073 - classifier_1_loss: 3.6532 - val_loss: 2.1907 - val_classifier_loss: 2.4835 - val_classifier_1_loss: 2.0653
# Epoch 31/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.8679 - classifier_loss: 4.4713 - classifier_1_loss: 3.6093
# Epoch 31: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_31-val_loss_2.0497.h5
# 1463/1463 [==============================] - 297s 158ms/step - loss: 3.8679 - classifier_loss: 4.4713 - classifier_1_loss: 3.6093 - val_loss: 2.1805 - val_classifier_loss: 2.4858 - val_classifier_1_loss: 2.0497
# Epoch 32/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.8321 - classifier_loss: 4.4436 - classifier_1_loss: 3.5700
# Epoch 32: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_32-val_loss_2.0479.h5
# 1463/1463 [==============================] - 299s 159ms/step - loss: 3.8321 - classifier_loss: 4.4436 - classifier_1_loss: 3.5700 - val_loss: 2.1730 - val_classifier_loss: 2.4649 - val_classifier_1_loss: 2.0479
# Epoch 33/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.7832 - classifier_loss: 4.3990 - classifier_1_loss: 3.5193
# Epoch 33: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_33-val_loss_1.9888.h5
# 1463/1463 [==============================] - 297s 158ms/step - loss: 3.7832 - classifier_loss: 4.3990 - classifier_1_loss: 3.5193 - val_loss: 2.1197 - val_classifier_loss: 2.4249 - val_classifier_1_loss: 1.9888
# Epoch 34/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.7493 - classifier_loss: 4.3680 - classifier_1_loss: 3.4842
# Epoch 34: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_34-val_loss_2.0720.h5
# 1463/1463 [==============================] - 294s 157ms/step - loss: 3.7493 - classifier_loss: 4.3680 - classifier_1_loss: 3.4842 - val_loss: 2.2000 - val_classifier_loss: 2.4987 - val_classifier_1_loss: 2.0720
# Epoch 35/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.7213 - classifier_loss: 4.3486 - classifier_1_loss: 3.4525
# Epoch 35: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_35-val_loss_1.9556.h5
# 1463/1463 [==============================] - 294s 157ms/step - loss: 3.7213 - classifier_loss: 4.3486 - classifier_1_loss: 3.4525 - val_loss: 2.0871 - val_classifier_loss: 2.3939 - val_classifier_1_loss: 1.9556
# Epoch 36/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.6868 - classifier_loss: 4.3196 - classifier_1_loss: 3.4157
# Epoch 36: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_36-val_loss_1.9187.h5
# 1463/1463 [==============================] - 300s 159ms/step - loss: 3.6868 - classifier_loss: 4.3196 - classifier_1_loss: 3.4157 - val_loss: 2.0509 - val_classifier_loss: 2.3595 - val_classifier_1_loss: 1.9187
# Epoch 37/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.6604 - classifier_loss: 4.3016 - classifier_1_loss: 3.3856
# Epoch 37: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_37-val_loss_1.9917.h5
# 1463/1463 [==============================] - 297s 158ms/step - loss: 3.6604 - classifier_loss: 4.3016 - classifier_1_loss: 3.3856 - val_loss: 2.1283 - val_classifier_loss: 2.4469 - val_classifier_1_loss: 1.9917
# Epoch 38/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.6288 - classifier_loss: 4.2750 - classifier_1_loss: 3.3519
# Epoch 38: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_38-val_loss_1.8905.h5
# 1463/1463 [==============================] - 297s 158ms/step - loss: 3.6288 - classifier_loss: 4.2750 - classifier_1_loss: 3.3519 - val_loss: 2.0218 - val_classifier_loss: 2.3282 - val_classifier_1_loss: 1.8905
# Epoch 39/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.5914 - classifier_loss: 4.2412 - classifier_1_loss: 3.3129
# Epoch 39: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_39-val_loss_1.9043.h5
# 1463/1463 [==============================] - 293s 158ms/step - loss: 3.5914 - classifier_loss: 4.2412 - classifier_1_loss: 3.3129 - val_loss: 2.0427 - val_classifier_loss: 2.3658 - val_classifier_1_loss: 1.9043
# Epoch 40/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.5632 - classifier_loss: 4.2161 - classifier_1_loss: 3.2834
# Epoch 40: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_40-val_loss_1.8650.h5
# 1463/1463 [==============================] - 298s 159ms/step - loss: 3.5632 - classifier_loss: 4.2161 - classifier_1_loss: 3.2834 - val_loss: 2.0028 - val_classifier_loss: 2.3242 - val_classifier_1_loss: 1.8650
# Epoch 41/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.5395 - classifier_loss: 4.1986 - classifier_1_loss: 3.2570
# Epoch 41: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_41-val_loss_1.8892.h5
# 1463/1463 [==============================] - 299s 159ms/step - loss: 3.5395 - classifier_loss: 4.1986 - classifier_1_loss: 3.2570 - val_loss: 2.0343 - val_classifier_loss: 2.3729 - val_classifier_1_loss: 1.8892
# Epoch 42/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.5154 - classifier_loss: 4.1773 - classifier_1_loss: 3.2318
# Epoch 42: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_42-val_loss_1.8276.h5
# 1463/1463 [==============================] - 298s 160ms/step - loss: 3.5154 - classifier_loss: 4.1773 - classifier_1_loss: 3.2318 - val_loss: 1.9665 - val_classifier_loss: 2.2907 - val_classifier_1_loss: 1.8276
# Epoch 43/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.4844 - classifier_loss: 4.1483 - classifier_1_loss: 3.1998
# Epoch 43: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_43-val_loss_1.8929.h5
# 1463/1463 [==============================] - 294s 157ms/step - loss: 3.4844 - classifier_loss: 4.1483 - classifier_1_loss: 3.1998 - val_loss: 2.0313 - val_classifier_loss: 2.3542 - val_classifier_1_loss: 1.8929
# Epoch 44/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.4640 - classifier_loss: 4.1339 - classifier_1_loss: 3.1769
# Epoch 44: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_44-val_loss_1.7673.h5
# 1463/1463 [==============================] - 299s 159ms/step - loss: 3.4640 - classifier_loss: 4.1339 - classifier_1_loss: 3.1769 - val_loss: 1.9098 - val_classifier_loss: 2.2423 - val_classifier_1_loss: 1.7673
# Epoch 45/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.4388 - classifier_loss: 4.1136 - classifier_1_loss: 3.1496
# Epoch 45: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_45-val_loss_1.7991.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 3.4388 - classifier_loss: 4.1136 - classifier_1_loss: 3.1496 - val_loss: 1.9501 - val_classifier_loss: 2.3023 - val_classifier_1_loss: 1.7991
# Epoch 46/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.4180 - classifier_loss: 4.0981 - classifier_1_loss: 3.1265
# Epoch 46: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_46-val_loss_1.7529.h5
# 1463/1463 [==============================] - 299s 160ms/step - loss: 3.4180 - classifier_loss: 4.0981 - classifier_1_loss: 3.1265 - val_loss: 1.8943 - val_classifier_loss: 2.2242 - val_classifier_1_loss: 1.7529
# Epoch 47/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.3916 - classifier_loss: 4.0719 - classifier_1_loss: 3.1001
# Epoch 47: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_47-val_loss_1.8339.h5
# 1463/1463 [==============================] - 294s 158ms/step - loss: 3.3916 - classifier_loss: 4.0719 - classifier_1_loss: 3.1001 - val_loss: 1.9808 - val_classifier_loss: 2.3235 - val_classifier_1_loss: 1.8339
# Epoch 48/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.3680 - classifier_loss: 4.0523 - classifier_1_loss: 3.0747
# Epoch 48: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_48-val_loss_1.7199.h5
# 1463/1463 [==============================] - 295s 159ms/step - loss: 3.3680 - classifier_loss: 4.0523 - classifier_1_loss: 3.0747 - val_loss: 1.8691 - val_classifier_loss: 2.2173 - val_classifier_1_loss: 1.7199
# Epoch 49/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.3521 - classifier_loss: 4.0387 - classifier_1_loss: 3.0578
# Epoch 49: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_49-val_loss_1.6891.h5
# 1463/1463 [==============================] - 297s 158ms/step - loss: 3.3521 - classifier_loss: 4.0387 - classifier_1_loss: 3.0578 - val_loss: 1.8321 - val_classifier_loss: 2.1656 - val_classifier_1_loss: 1.6891
# Epoch 50/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.3307 - classifier_loss: 4.0236 - classifier_1_loss: 3.0337
# Epoch 50: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_50-val_loss_1.6998.h5
# 1463/1463 [==============================] - 293s 157ms/step - loss: 3.3307 - classifier_loss: 4.0236 - classifier_1_loss: 3.0337 - val_loss: 1.8447 - val_classifier_loss: 2.1829 - val_classifier_1_loss: 1.6998
# Epoch 51/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.2983 - classifier_loss: 3.9905 - classifier_1_loss: 3.0016
# Epoch 51: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_51-val_loss_1.6897.h5
# 1463/1463 [==============================] - 293s 158ms/step - loss: 3.2983 - classifier_loss: 3.9905 - classifier_1_loss: 3.0016 - val_loss: 1.8340 - val_classifier_loss: 2.1707 - val_classifier_1_loss: 1.6897
# Epoch 52/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.2763 - classifier_loss: 3.9704 - classifier_1_loss: 2.9788
# Epoch 52: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_52-val_loss_1.6953.h5
# 1463/1463 [==============================] - 295s 159ms/step - loss: 3.2763 - classifier_loss: 3.9704 - classifier_1_loss: 2.9788 - val_loss: 1.8430 - val_classifier_loss: 2.1874 - val_classifier_1_loss: 1.6953
# Epoch 53/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.2633 - classifier_loss: 3.9629 - classifier_1_loss: 2.9635
# Epoch 53: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_53-val_loss_1.6586.h5
# 1463/1463 [==============================] - 294s 158ms/step - loss: 3.2633 - classifier_loss: 3.9629 - classifier_1_loss: 2.9635 - val_loss: 1.8038 - val_classifier_loss: 2.1424 - val_classifier_1_loss: 1.6586
# Epoch 54/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.2444 - classifier_loss: 3.9478 - classifier_1_loss: 2.9429
# Epoch 54: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_54-val_loss_1.6951.h5
# 1463/1463 [==============================] - 295s 158ms/step - loss: 3.2444 - classifier_loss: 3.9478 - classifier_1_loss: 2.9429 - val_loss: 1.8398 - val_classifier_loss: 2.1774 - val_classifier_1_loss: 1.6951
# Epoch 55/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.2202 - classifier_loss: 3.9259 - classifier_1_loss: 2.9177
# Epoch 55: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_55-val_loss_1.6368.h5
# 1463/1463 [==============================] - 296s 159ms/step - loss: 3.2202 - classifier_loss: 3.9259 - classifier_1_loss: 2.9177 - val_loss: 1.7863 - val_classifier_loss: 2.1353 - val_classifier_1_loss: 1.6368
# Epoch 56/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.2012 - classifier_loss: 3.9095 - classifier_1_loss: 2.8977
# Epoch 56: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_56-val_loss_1.5853.h5
# 1463/1463 [==============================] - 298s 159ms/step - loss: 3.2012 - classifier_loss: 3.9095 - classifier_1_loss: 2.8977 - val_loss: 1.7336 - val_classifier_loss: 2.0797 - val_classifier_1_loss: 1.5853
# Epoch 57/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.1811 - classifier_loss: 3.8912 - classifier_1_loss: 2.8767
# Epoch 57: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_57-val_loss_1.5911.h5
# 1463/1463 [==============================] - 295s 158ms/step - loss: 3.1811 - classifier_loss: 3.8912 - classifier_1_loss: 2.8767 - val_loss: 1.7373 - val_classifier_loss: 2.0785 - val_classifier_1_loss: 1.5911
# Epoch 58/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.1657 - classifier_loss: 3.8772 - classifier_1_loss: 2.8607
# Epoch 58: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_58-val_loss_1.5731.h5
# 1463/1463 [==============================] - 297s 158ms/step - loss: 3.1657 - classifier_loss: 3.8772 - classifier_1_loss: 2.8607 - val_loss: 1.7251 - val_classifier_loss: 2.0798 - val_classifier_1_loss: 1.5731
# Epoch 59/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.1541 - classifier_loss: 3.8685 - classifier_1_loss: 2.8479
# Epoch 59: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_59-val_loss_1.5879.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 3.1541 - classifier_loss: 3.8685 - classifier_1_loss: 2.8479 - val_loss: 1.7409 - val_classifier_loss: 2.0980 - val_classifier_1_loss: 1.5879
# Epoch 60/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.1300 - classifier_loss: 3.8488 - classifier_1_loss: 2.8219
# Epoch 60: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_60-val_loss_1.5496.h5
# 1463/1463 [==============================] - 297s 157ms/step - loss: 3.1300 - classifier_loss: 3.8488 - classifier_1_loss: 2.8219 - val_loss: 1.6985 - val_classifier_loss: 2.0459 - val_classifier_1_loss: 1.5496
# Epoch 61/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.1177 - classifier_loss: 3.8399 - classifier_1_loss: 2.8082
# Epoch 61: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_61-val_loss_1.5612.h5
# 1463/1463 [==============================] - 297s 157ms/step - loss: 3.1177 - classifier_loss: 3.8399 - classifier_1_loss: 2.8082 - val_loss: 1.7135 - val_classifier_loss: 2.0691 - val_classifier_1_loss: 1.5612
# Epoch 62/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.0941 - classifier_loss: 3.8165 - classifier_1_loss: 2.7845
# Epoch 62: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_62-val_loss_1.5192.h5
# 1463/1463 [==============================] - 294s 158ms/step - loss: 3.0941 - classifier_loss: 3.8165 - classifier_1_loss: 2.7845 - val_loss: 1.6682 - val_classifier_loss: 2.0159 - val_classifier_1_loss: 1.5192
# Epoch 63/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.0812 - classifier_loss: 3.8077 - classifier_1_loss: 2.7698
# Epoch 63: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_63-val_loss_1.5152.h5
# 1463/1463 [==============================] - 295s 158ms/step - loss: 3.0812 - classifier_loss: 3.8077 - classifier_1_loss: 2.7698 - val_loss: 1.6704 - val_classifier_loss: 2.0325 - val_classifier_1_loss: 1.5152
# Epoch 64/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.0670 - classifier_loss: 3.7948 - classifier_1_loss: 2.7551
# Epoch 64: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_64-val_loss_1.4901.h5
# 1463/1463 [==============================] - 294s 158ms/step - loss: 3.0670 - classifier_loss: 3.7948 - classifier_1_loss: 2.7551 - val_loss: 1.6428 - val_classifier_loss: 1.9990 - val_classifier_1_loss: 1.4901
# Epoch 65/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.0482 - classifier_loss: 3.7764 - classifier_1_loss: 2.7361
# Epoch 65: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_65-val_loss_1.5170.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 3.0482 - classifier_loss: 3.7764 - classifier_1_loss: 2.7361 - val_loss: 1.6747 - val_classifier_loss: 2.0429 - val_classifier_1_loss: 1.5170
# Epoch 66/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.0356 - classifier_loss: 3.7670 - classifier_1_loss: 2.7222
# Epoch 66: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_66-val_loss_1.4536.h5
# 1463/1463 [==============================] - 297s 160ms/step - loss: 3.0356 - classifier_loss: 3.7670 - classifier_1_loss: 2.7222 - val_loss: 1.6070 - val_classifier_loss: 1.9649 - val_classifier_1_loss: 1.4536
# Epoch 67/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.0202 - classifier_loss: 3.7540 - classifier_1_loss: 2.7058
# Epoch 67: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_67-val_loss_1.4970.h5
# 1463/1463 [==============================] - 296s 159ms/step - loss: 3.0202 - classifier_loss: 3.7540 - classifier_1_loss: 2.7058 - val_loss: 1.6558 - val_classifier_loss: 2.0264 - val_classifier_1_loss: 1.4970
# Epoch 68/200
# 1463/1463 [==============================] - ETA: 0s - loss: 3.0027 - classifier_loss: 3.7397 - classifier_1_loss: 2.6868
# Epoch 68: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_68-val_loss_1.4447.h5
# 1463/1463 [==============================] - 298s 159ms/step - loss: 3.0027 - classifier_loss: 3.7397 - classifier_1_loss: 2.6868 - val_loss: 1.5992 - val_classifier_loss: 1.9597 - val_classifier_1_loss: 1.4447
# Epoch 69/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.9875 - classifier_loss: 3.7242 - classifier_1_loss: 2.6717
# Epoch 69: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_69-val_loss_1.5122.h5
# 1463/1463 [==============================] - 295s 159ms/step - loss: 2.9875 - classifier_loss: 3.7242 - classifier_1_loss: 2.6717 - val_loss: 1.6695 - val_classifier_loss: 2.0368 - val_classifier_1_loss: 1.5122
# Epoch 70/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.9740 - classifier_loss: 3.7133 - classifier_1_loss: 2.6572
# Epoch 70: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_70-val_loss_1.4446.h5
# 1463/1463 [==============================] - 295s 159ms/step - loss: 2.9740 - classifier_loss: 3.7133 - classifier_1_loss: 2.6572 - val_loss: 1.6048 - val_classifier_loss: 1.9786 - val_classifier_1_loss: 1.4446
# Epoch 71/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.9644 - classifier_loss: 3.7029 - classifier_1_loss: 2.6479
# Epoch 71: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_71-val_loss_1.5098.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 2.9644 - classifier_loss: 3.7029 - classifier_1_loss: 2.6479 - val_loss: 1.6684 - val_classifier_loss: 2.0385 - val_classifier_1_loss: 1.5098
# Epoch 72/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.9456 - classifier_loss: 3.6890 - classifier_1_loss: 2.6270
# Epoch 72: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_72-val_loss_1.4035.h5
# 1463/1463 [==============================] - 296s 159ms/step - loss: 2.9456 - classifier_loss: 3.6890 - classifier_1_loss: 2.6270 - val_loss: 1.5603 - val_classifier_loss: 1.9261 - val_classifier_1_loss: 1.4035
# Epoch 73/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.9298 - classifier_loss: 3.6752 - classifier_1_loss: 2.6103
# Epoch 73: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_73-val_loss_1.3949.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 2.9298 - classifier_loss: 3.6752 - classifier_1_loss: 2.6103 - val_loss: 1.5502 - val_classifier_loss: 1.9127 - val_classifier_1_loss: 1.3949
# Epoch 74/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.9197 - classifier_loss: 3.6678 - classifier_1_loss: 2.5991
# Epoch 74: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_74-val_loss_1.4071.h5
# 1463/1463 [==============================] - 297s 160ms/step - loss: 2.9197 - classifier_loss: 3.6678 - classifier_1_loss: 2.5991 - val_loss: 1.5636 - val_classifier_loss: 1.9289 - val_classifier_1_loss: 1.4071
# Epoch 75/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.9061 - classifier_loss: 3.6564 - classifier_1_loss: 2.5846
# Epoch 75: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_75-val_loss_1.3672.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 2.9061 - classifier_loss: 3.6564 - classifier_1_loss: 2.5846 - val_loss: 1.5253 - val_classifier_loss: 1.8944 - val_classifier_1_loss: 1.3672
# Epoch 76/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8885 - classifier_loss: 3.6413 - classifier_1_loss: 2.5659
# Epoch 76: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_76-val_loss_1.3673.h5
# 1463/1463 [==============================] - 294s 160ms/step - loss: 2.8885 - classifier_loss: 3.6413 - classifier_1_loss: 2.5659 - val_loss: 1.5265 - val_classifier_loss: 1.8979 - val_classifier_1_loss: 1.3673
# Epoch 77/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8792 - classifier_loss: 3.6310 - classifier_1_loss: 2.5569
# Epoch 77: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_77-val_loss_1.3582.h5
# 1463/1463 [==============================] - 295s 159ms/step - loss: 2.8792 - classifier_loss: 3.6310 - classifier_1_loss: 2.5569 - val_loss: 1.5195 - val_classifier_loss: 1.8959 - val_classifier_1_loss: 1.3582
# Epoch 78/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8630 - classifier_loss: 3.6193 - classifier_1_loss: 2.5388
# Epoch 78: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_78-val_loss_1.3507.h5
# 1463/1463 [==============================] - 297s 159ms/step - loss: 2.8630 - classifier_loss: 3.6193 - classifier_1_loss: 2.5388 - val_loss: 1.5085 - val_classifier_loss: 1.8765 - val_classifier_1_loss: 1.3507
# Epoch 79/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8512 - classifier_loss: 3.6059 - classifier_1_loss: 2.5278
# Epoch 79: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_79-val_loss_1.3531.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 2.8512 - classifier_loss: 3.6059 - classifier_1_loss: 2.5278 - val_loss: 1.5146 - val_classifier_loss: 1.8914 - val_classifier_1_loss: 1.3531
# Epoch 80/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8445 - classifier_loss: 3.6005 - classifier_1_loss: 2.5204
# Epoch 80: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_80-val_loss_1.3581.h5
# 1463/1463 [==============================] - 293s 158ms/step - loss: 2.8445 - classifier_loss: 3.6005 - classifier_1_loss: 2.5204 - val_loss: 1.5220 - val_classifier_loss: 1.9044 - val_classifier_1_loss: 1.3581
# Epoch 81/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8283 - classifier_loss: 3.5860 - classifier_1_loss: 2.5036
# Epoch 81: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_81-val_loss_1.3742.h5
# 1463/1463 [==============================] - 293s 158ms/step - loss: 2.8283 - classifier_loss: 3.5860 - classifier_1_loss: 2.5036 - val_loss: 1.5404 - val_classifier_loss: 1.9283 - val_classifier_1_loss: 1.3742
# Epoch 82/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8191 - classifier_loss: 3.5812 - classifier_1_loss: 2.4924
# Epoch 82: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_82-val_loss_1.3370.h5
# 1463/1463 [==============================] - 295s 159ms/step - loss: 2.8191 - classifier_loss: 3.5812 - classifier_1_loss: 2.4924 - val_loss: 1.5005 - val_classifier_loss: 1.8821 - val_classifier_1_loss: 1.3370
# Epoch 83/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.8026 - classifier_loss: 3.5644 - classifier_1_loss: 2.4761
# Epoch 83: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_83-val_loss_1.3210.h5
# 1463/1463 [==============================] - 296s 160ms/step - loss: 2.8026 - classifier_loss: 3.5644 - classifier_1_loss: 2.4761 - val_loss: 1.4836 - val_classifier_loss: 1.8630 - val_classifier_1_loss: 1.3210
# Epoch 84/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.7954 - classifier_loss: 3.5597 - classifier_1_loss: 2.4679
# Epoch 84: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_84-val_loss_1.3011.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 2.7954 - classifier_loss: 3.5597 - classifier_1_loss: 2.4679 - val_loss: 1.4644 - val_classifier_loss: 1.8454 - val_classifier_1_loss: 1.3011
# Epoch 85/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.7772 - classifier_loss: 3.5404 - classifier_1_loss: 2.4501
# Epoch 85: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_85-val_loss_1.2974.h5
# 1463/1463 [==============================] - 291s 159ms/step - loss: 2.7772 - classifier_loss: 3.5404 - classifier_1_loss: 2.4501 - val_loss: 1.4603 - val_classifier_loss: 1.8405 - val_classifier_1_loss: 1.2974
# Epoch 86/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.7673 - classifier_loss: 3.5304 - classifier_1_loss: 2.4402
# Epoch 86: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_86-val_loss_1.2998.h5
# 1463/1463 [==============================] - 296s 159ms/step - loss: 2.7673 - classifier_loss: 3.5304 - classifier_1_loss: 2.4402 - val_loss: 1.4643 - val_classifier_loss: 1.8481 - val_classifier_1_loss: 1.2998
# Epoch 87/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.7560 - classifier_loss: 3.5221 - classifier_1_loss: 2.4277
# Epoch 87: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_87-val_loss_1.2921.h5
# 1463/1463 [==============================] - 290s 159ms/step - loss: 2.7560 - classifier_loss: 3.5221 - classifier_1_loss: 2.4277 - val_loss: 1.4530 - val_classifier_loss: 1.8285 - val_classifier_1_loss: 1.2921
# Epoch 88/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.7402 - classifier_loss: 3.5069 - classifier_1_loss: 2.4116
# Epoch 88: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_88-val_loss_1.2694.h5
# 1463/1463 [==============================] - 292s 159ms/step - loss: 2.7402 - classifier_loss: 3.5069 - classifier_1_loss: 2.4116 - val_loss: 1.4341 - val_classifier_loss: 1.8185 - val_classifier_1_loss: 1.2694
# Epoch 89/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.7263 - classifier_loss: 3.4945 - classifier_1_loss: 2.3971
# Epoch 89: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_89-val_loss_1.2542.h5
# 1463/1463 [==============================] - 294s 159ms/step - loss: 2.7263 - classifier_loss: 3.4945 - classifier_1_loss: 2.3971 - val_loss: 1.4190 - val_classifier_loss: 1.8036 - val_classifier_1_loss: 1.2542
# Epoch 90/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.7185 - classifier_loss: 3.4855 - classifier_1_loss: 2.3898
# Epoch 90: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_90-val_loss_1.2565.h5
# 1463/1463 [==============================] - 294s 160ms/step - loss: 2.7185 - classifier_loss: 3.4855 - classifier_1_loss: 2.3898 - val_loss: 1.4216 - val_classifier_loss: 1.8070 - val_classifier_1_loss: 1.2565
# Epoch 91/200
# ...
# Epoch 171: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_171-val_loss_0.8173.h5
# 1463/1463 [==============================] - 289s 157ms/step - loss: 2.1325 - classifier_loss: 2.9434 - classifier_1_loss: 1.7850 - val_loss: 0.9941 - val_classifier_loss: 1.4067 - val_classifier_1_loss: 0.8173
# Epoch 172/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1286 - classifier_loss: 2.9388 - classifier_1_loss: 1.7814
# Epoch 172: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_172-val_loss_0.8172.h5
# 1463/1463 [==============================] - 290s 158ms/step - loss: 2.1286 - classifier_loss: 2.9388 - classifier_1_loss: 1.7814 - val_loss: 0.9943 - val_classifier_loss: 1.4076 - val_classifier_1_loss: 0.8172
# Epoch 173/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1216 - classifier_loss: 2.9298 - classifier_1_loss: 1.7753
# Epoch 173: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_173-val_loss_0.8146.h5
# 1463/1463 [==============================] - 288s 158ms/step - loss: 2.1216 - classifier_loss: 2.9298 - classifier_1_loss: 1.7753 - val_loss: 0.9924 - val_classifier_loss: 1.4073 - val_classifier_1_loss: 0.8146
# Epoch 174/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1228 - classifier_loss: 2.9316 - classifier_1_loss: 1.7762
# Epoch 174: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_174-val_loss_0.8122.h5
# 1463/1463 [==============================] - 289s 158ms/step - loss: 2.1228 - classifier_loss: 2.9316 - classifier_1_loss: 1.7762 - val_loss: 0.9889 - val_classifier_loss: 1.4014 - val_classifier_1_loss: 0.8122
# Epoch 175/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1197 - classifier_loss: 2.9303 - classifier_1_loss: 1.7724
# Epoch 175: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_175-val_loss_0.8109.h5
# 1463/1463 [==============================] - 290s 158ms/step - loss: 2.1197 - classifier_loss: 2.9303 - classifier_1_loss: 1.7724 - val_loss: 0.9884 - val_classifier_loss: 1.4025 - val_classifier_1_loss: 0.8109
# Epoch 176/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1171 - classifier_loss: 2.9285 - classifier_1_loss: 1.7693
# Epoch 176: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_176-val_loss_0.8099.h5
# 1463/1463 [==============================] - 288s 158ms/step - loss: 2.1171 - classifier_loss: 2.9285 - classifier_1_loss: 1.7693 - val_loss: 0.9874 - val_classifier_loss: 1.4016 - val_classifier_1_loss: 0.8099
# Epoch 177/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1144 - classifier_loss: 2.9243 - classifier_1_loss: 1.7673
# Epoch 177: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_177-val_loss_0.8094.h5
# 1463/1463 [==============================] - 292s 159ms/step - loss: 2.1144 - classifier_loss: 2.9243 - classifier_1_loss: 1.7673 - val_loss: 0.9867 - val_classifier_loss: 1.4004 - val_classifier_1_loss: 0.8094
# Epoch 178/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1107 - classifier_loss: 2.9197 - classifier_1_loss: 1.7640
# Epoch 178: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_178-val_loss_0.8066.h5
# 1463/1463 [==============================] - 290s 158ms/step - loss: 2.1107 - classifier_loss: 2.9197 - classifier_1_loss: 1.7640 - val_loss: 0.9837 - val_classifier_loss: 1.3969 - val_classifier_1_loss: 0.8066
# Epoch 179/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1089 - classifier_loss: 2.9198 - classifier_1_loss: 1.7614
# Epoch 179: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_179-val_loss_0.8052.h5
# 1463/1463 [==============================] - 289s 159ms/step - loss: 2.1089 - classifier_loss: 2.9198 - classifier_1_loss: 1.7614 - val_loss: 0.9821 - val_classifier_loss: 1.3947 - val_classifier_1_loss: 0.8052
# Epoch 180/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1082 - classifier_loss: 2.9160 - classifier_1_loss: 1.7620
# Epoch 180: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_180-val_loss_0.8052.h5
# 1463/1463 [==============================] - 291s 159ms/step - loss: 2.1082 - classifier_loss: 2.9160 - classifier_1_loss: 1.7620 - val_loss: 0.9815 - val_classifier_loss: 1.3929 - val_classifier_1_loss: 0.8052
# Epoch 181/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1070 - classifier_loss: 2.9171 - classifier_1_loss: 1.7598
# Epoch 181: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_181-val_loss_0.8049.h5
# 1463/1463 [==============================] - 292s 159ms/step - loss: 2.1070 - classifier_loss: 2.9171 - classifier_1_loss: 1.7598 - val_loss: 0.9819 - val_classifier_loss: 1.3949 - val_classifier_1_loss: 0.8049
# Epoch 182/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1023 - classifier_loss: 2.9123 - classifier_1_loss: 1.7551
# Epoch 182: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_182-val_loss_0.8026.h5
# 1463/1463 [==============================] - 292s 159ms/step - loss: 2.1023 - classifier_loss: 2.9123 - classifier_1_loss: 1.7551 - val_loss: 0.9792 - val_classifier_loss: 1.3914 - val_classifier_1_loss: 0.8026
# Epoch 183/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1052 - classifier_loss: 2.9148 - classifier_1_loss: 1.7582
# Epoch 183: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_183-val_loss_0.8043.h5
# 1463/1463 [==============================] - 295s 158ms/step - loss: 2.1052 - classifier_loss: 2.9148 - classifier_1_loss: 1.7582 - val_loss: 0.9816 - val_classifier_loss: 1.3953 - val_classifier_1_loss: 0.8043
# Epoch 184/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.1003 - classifier_loss: 2.9102 - classifier_1_loss: 1.7533
# Epoch 184: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_184-val_loss_0.8022.h5
# 1463/1463 [==============================] - 293s 160ms/step - loss: 2.1003 - classifier_loss: 2.9102 - classifier_1_loss: 1.7533 - val_loss: 0.9795 - val_classifier_loss: 1.3930 - val_classifier_1_loss: 0.8022
# Epoch 185/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0987 - classifier_loss: 2.9078 - classifier_1_loss: 1.7519
# Epoch 185: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_185-val_loss_0.8017.h5
# 1463/1463 [==============================] - 291s 159ms/step - loss: 2.0987 - classifier_loss: 2.9078 - classifier_1_loss: 1.7519 - val_loss: 0.9784 - val_classifier_loss: 1.3907 - val_classifier_1_loss: 0.8017
# Epoch 186/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0991 - classifier_loss: 2.9087 - classifier_1_loss: 1.7521
# Epoch 186: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_186-val_loss_0.8004.h5
# 1463/1463 [==============================] - 293s 160ms/step - loss: 2.0991 - classifier_loss: 2.9087 - classifier_1_loss: 1.7521 - val_loss: 0.9772 - val_classifier_loss: 1.3895 - val_classifier_1_loss: 0.8004
# Epoch 187/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0993 - classifier_loss: 2.9089 - classifier_1_loss: 1.7524
# Epoch 187: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_187-val_loss_0.8011.h5
# 1463/1463 [==============================] - 292s 160ms/step - loss: 2.0993 - classifier_loss: 2.9089 - classifier_1_loss: 1.7524 - val_loss: 0.9778 - val_classifier_loss: 1.3901 - val_classifier_1_loss: 0.8011
# Epoch 188/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0963 - classifier_loss: 2.9056 - classifier_1_loss: 1.7495
# Epoch 188: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_188-val_loss_0.8010.h5
# 1463/1463 [==============================] - 298s 160ms/step - loss: 2.0963 - classifier_loss: 2.9056 - classifier_1_loss: 1.7495 - val_loss: 0.9777 - val_classifier_loss: 1.3902 - val_classifier_1_loss: 0.8010
# Epoch 189/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0997 - classifier_loss: 2.9113 - classifier_1_loss: 1.7519
# Epoch 189: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_189-val_loss_0.7990.h5
# 1463/1463 [==============================] - 290s 159ms/step - loss: 2.0997 - classifier_loss: 2.9113 - classifier_1_loss: 1.7519 - val_loss: 0.9760 - val_classifier_loss: 1.3891 - val_classifier_1_loss: 0.7990
# Epoch 190/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0948 - classifier_loss: 2.9063 - classifier_1_loss: 1.7471
# Epoch 190: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_190-val_loss_0.7986.h5
# 1463/1463 [==============================] - 291s 159ms/step - loss: 2.0948 - classifier_loss: 2.9063 - classifier_1_loss: 1.7471 - val_loss: 0.9758 - val_classifier_loss: 1.3891 - val_classifier_1_loss: 0.7986
# Epoch 191/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0981 - classifier_loss: 2.9107 - classifier_1_loss: 1.7498
# Epoch 191: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_191-val_loss_0.7997.h5
# 1463/1463 [==============================] - 292s 159ms/step - loss: 2.0981 - classifier_loss: 2.9107 - classifier_1_loss: 1.7498 - val_loss: 0.9764 - val_classifier_loss: 1.3889 - val_classifier_1_loss: 0.7997
# Epoch 192/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0943 - classifier_loss: 2.9031 - classifier_1_loss: 1.7477
# Epoch 192: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_192-val_loss_0.7979.h5
# 1463/1463 [==============================] - 291s 160ms/step - loss: 2.0943 - classifier_loss: 2.9031 - classifier_1_loss: 1.7477 - val_loss: 0.9754 - val_classifier_loss: 1.3897 - val_classifier_1_loss: 0.7979
# Epoch 193/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0972 - classifier_loss: 2.9049 - classifier_1_loss: 1.7510
# Epoch 193: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_193-val_loss_0.7980.h5
# 1463/1463 [==============================] - 293s 160ms/step - loss: 2.0972 - classifier_loss: 2.9049 - classifier_1_loss: 1.7510 - val_loss: 0.9748 - val_classifier_loss: 1.3874 - val_classifier_1_loss: 0.7980
# Epoch 194/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0930 - classifier_loss: 2.9023 - classifier_1_loss: 1.7462
# Epoch 194: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_194-val_loss_0.7973.h5
# 1463/1463 [==============================] - 295s 161ms/step - loss: 2.0930 - classifier_loss: 2.9023 - classifier_1_loss: 1.7462 - val_loss: 0.9741 - val_classifier_loss: 1.3867 - val_classifier_1_loss: 0.7973
# Epoch 195/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0977 - classifier_loss: 2.9063 - classifier_1_loss: 1.7511
# Epoch 195: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_195-val_loss_0.7976.h5
# 1463/1463 [==============================] - 292s 159ms/step - loss: 2.0977 - classifier_loss: 2.9063 - classifier_1_loss: 1.7511 - val_loss: 0.9747 - val_classifier_loss: 1.3880 - val_classifier_1_loss: 0.7976
# Epoch 196/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0934 - classifier_loss: 2.9053 - classifier_1_loss: 1.7455
# Epoch 196: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_196-val_loss_0.7974.h5
# 1463/1463 [==============================] - 293s 160ms/step - loss: 2.0934 - classifier_loss: 2.9053 - classifier_1_loss: 1.7455 - val_loss: 0.9742 - val_classifier_loss: 1.3868 - val_classifier_1_loss: 0.7974
# Epoch 197/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0930 - classifier_loss: 2.9007 - classifier_1_loss: 1.7468
# Epoch 197: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_197-val_loss_0.7981.h5
# 1463/1463 [==============================] - 288s 159ms/step - loss: 2.0930 - classifier_loss: 2.9007 - classifier_1_loss: 1.7468 - val_loss: 0.9748 - val_classifier_loss: 1.3871 - val_classifier_1_loss: 0.7981
# Epoch 198/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0938 - classifier_loss: 2.9040 - classifier_1_loss: 1.7465
# Epoch 198: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_198-val_loss_0.7967.h5
# 1463/1463 [==============================] - 293s 160ms/step - loss: 2.0938 - classifier_loss: 2.9040 - classifier_1_loss: 1.7465 - val_loss: 0.9735 - val_classifier_loss: 1.3861 - val_classifier_1_loss: 0.7967
# Epoch 199/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0933 - classifier_loss: 2.9043 - classifier_1_loss: 1.7457
# Epoch 199: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_199-val_loss_0.7974.h5
# 1463/1463 [==============================] - 291s 159ms/step - loss: 2.0933 - classifier_loss: 2.9043 - classifier_1_loss: 1.7457 - val_loss: 0.9741 - val_classifier_loss: 1.3865 - val_classifier_1_loss: 0.7974
# Epoch 200/200
# 1463/1463 [==============================] - ETA: 0s - loss: 2.0936 - classifier_loss: 2.9062 - classifier_1_loss: 1.7453
# Epoch 200: saving model to /content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0824)-deep-wide/weights/epoch_200-val_loss_0.7969.h5
# 1463/1463 [==============================] - 293s 159ms/step - loss: 2.0936 - classifier_loss: 2.9062 - classifier_1_loss: 1.7453 - val_loss: 0.9736 - val_classifier_loss: 1.3861 - val_classifier_1_loss: 0.7969

# %% [markdown]
# ## evaluation

# %%
class CustomTokenizer(nn.Module):
  def __init__(self, args):
    super(CustomTokenizer, self).__init__()
    self.args = args
    with open(args.path + 'Data Sources/character_to_prediction_index.json', 'r') as f:
      self.character_to_prediction_index = json.load(f)

    self.prediction_index_to_character = {value: key for key, value in self.character_to_prediction_index.items()}
    self.prediction_index_to_character.update({
                                               args.decoder_bos_token : '<s>',
                                               args.decoder_eos_token : '</s>',
                                               args.decoder_pad_token : '<pad>',
                                               args.blank_token : 'ϵ'
                                               })
    self.special_tokens = [
        args.decoder_bos_token,
        args.decoder_eos_token,
        args.decoder_pad_token
        ]


  def tokenize(self, x):
    tokenized_x = list()
    for i in range(len(x)):
      tokenized_x.append(x[i])
    return tokenized_x

  def encode(self, x):
    encoded_x = list()
    for i in range(len(x)):
      encoded_x.append(self.character_to_prediction_index[x[i]])
    return encoded_x

  def decode(self, x, skip_speical_tokens=True):
    if torch.is_tensor(x):
      x = x.tolist()
    decoded_x = list()
    for i in range(len(x)):
      if skip_speical_tokens:
        if x[i] not in self.special_tokens:
          decoded_x.append(self.prediction_index_to_character[x[i]])
      else:
        decoded_x.append(self.prediction_index_to_character[x[i]])
    return ''.join(decoded_x)

  def batch_decode(self, batch_x, skip_speical_tokens=True):
    if torch.is_tensor(batch_x):
      batch_x = batch_x.tolist()
    decoded_x = list()
    for i in range(len(batch_x)):
      x = batch_x[i]
      decoded_x.append(self.decode(x, skip_speical_tokens=skip_speical_tokens))
    return decoded_x

tokenizer = CustomTokenizer(args)

# %%
with strategy.scope():
  model = get_model()
  inputs = keras.layers.Input(shape = (args.max_label, args.input_dim*2))
  model(inputs)
  model.load_weights('/content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0818)-deep/weights/epoch_185-val_loss_0.4702.h5')

  model.compile(
      optimizer=optimizer,
      jit_compile=True
  )

  model.compile(
    loss=loss,
  )

# %%
with strategy.scope():
  model.evaluate(val_loader)

# %%
def decode_phrase(pred):
    x = tf.argmax(pred, axis=1)
    diff = tf.not_equal(x[:-1], x[1:])
    adjacent_indices = tf.where(diff)[:, 0]
    x = tf.gather(x, adjacent_indices)
    mask = x < 59
    x = tf.boolean_mask(x, mask, axis=0)
    return x

model = get_model()
inputs = keras.layers.Input(shape = (args.max_label, args.input_dim*2))
model(inputs)
model.load_weights('/content/drive/MyDrive/Kaggle/Google - American Sign Language Fingerspelling Recognition/Model/keras/simple(0818)-deep/weights/epoch_185-val_loss_0.4702.h5')

preds, trues = [], []
for batch in tqdm(val_loader):
    X, y = batch
    _, batch_pred = model(X)
    y = y.numpy()
    for i in range(X.shape[0]):
        pred = decode_phrase(batch_pred[i]).numpy()
        pred = tokenizer.decode(pred)
        true = tokenizer.decode(y[i])
        preds.append(pred)
        trues.append(true)

levenshtein_score(preds, trues)
